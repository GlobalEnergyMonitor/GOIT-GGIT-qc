# %%
import pandas
import json

# %%
pandas.read_json('/Users/baird/Dropbox/_gem-docs/external-orgs/earthjustice/station_0-1.json')
# Out:
#            type                                               data
# rows          1  [{'LAT': '42.33257', 'LON': '-70.98719', 'SPEE...
# areaShips     1                                               2335

# %%
file = open('/Users/baird/Dropbox/_gem-docs/external-orgs/earthjustice/station_0-1.json')
data = json.load(file)

# %%
pandas.DataFrame(data['data']['rows'])
# Out:
#             LAT        LON SPEED COURSE HEADING ELAPSED    DESTINATION FLAG  \
# 0      42.33257  -70.98719    78    273     272       0         BOSTON   LR
# 1        6.4305   3.337632     0    122     308       1          LAGOS   SG
# 2      41.49677    -81.723     0    217      54       1       SHUTTLES   US
# 3      44.03703    9.22885   106    130     129       0  IT GOA>IT SPE   LR
# 4      17.12816  -62.11969   172    264     260       1          KNBAS   VC
# ...         ...        ...   ...    ...     ...     ...            ...  ...
# 2330  -3.112293  -7.352088    97    147    None      29            NaN  NaN
# 2331  -5.607378  -6.881757    98    146    None      29            NaN  NaN
# 2332   8.208878   -24.8054   126    207    None     584         BR RIG   HK
# 2333    6.43999  -25.69832   129    205    None      29            NaN  NaN
# 2334   4.431993  -26.74682   171    135    None      29            NaN  NaN
#
#      LENGTH  ROT  ... SHIPTYPE  \
# ...

# %%
file_list = ['/Users/baird/Dropbox/_gem-docs/external-orgs/earthjustice/station_0-1.json',
             '/Users/baird/Dropbox/_gem-docs/external-orgs/earthjustice/station_0-2.json',
             '/Users/baird/Dropbox/_gem-docs/external-orgs/earthjustice/station_0-3.json',
             '/Users/baird/Dropbox/_gem-docs/external-orgs/earthjustice/station_0-4.json',
             '/Users/baird/Dropbox/_gem-docs/external-orgs/earthjustice/station_0-5.json',
             '/Users/baird/Dropbox/_gem-docs/external-orgs/earthjustice/station_0-6.json',
             '/Users/baird/Dropbox/_gem-docs/external-orgs/earthjustice/station_0-7.json',
             '/Users/baird/Dropbox/_gem-docs/external-orgs/earthjustice/station_0-8.json']

file = open('/Users/baird/Dropbox/_gem-docs/external-orgs/earthjustice/station_0-1.json')
data = json.load(file)
marine_traffic_df = pandas.DataFrame(data['data']['rows'])
for f in file_list[1:]:
    file = open(f)
    data = json.load(file)
    temp_df = pandas.DataFrame(data['data']['rows'])
    marine_traffic_df = pandas.concat([marine_traffic_df, temp_df], ignore_index=True)

# %%
marine_traffic_df.loc[marine_traffic_df.GT_SHIPTYPE=='18'].to_csv('/Users/Baird/Dropbox/_gem-docs/external-orgs/earthjustice/MarineTraffic-LNGTankers-2024-04-30.csv')
