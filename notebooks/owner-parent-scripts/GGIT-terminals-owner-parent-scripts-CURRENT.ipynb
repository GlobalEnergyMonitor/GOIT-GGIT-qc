# %% [markdown]
# # owner-parent string formatting code
#
# NOTE: owner/parent research is incomplete; presume all owners are parents if we haven't updated them yet

# %%
import pandas
import pygsheets
import datetime
import numpy

# %%
gc = pygsheets.authorize(service_account_env_var='GDRIVE_API_CREDENTIALS')
spreadsheet = gc.open_by_key('1tcS6Wd-Wp-LTDpLzFgJY_RSNDnbyubW3J_9HKIAys4A')
#spreadsheet = gc.open_by_key('129b9YeQn7uAIsMgyB5uleT2QZXYxjD_UetnqwVyoRaI')

#spreadsheet[1] "Gas Pipelines" tab is the second index
terms_df_orig = spreadsheet.worksheet('title', 'Terminals').get_as_df(start='A3')
terms_df_orig.replace('--',numpy.nan,inplace=True)
# Out:
# /var/folders/fl/t07mc8053p33mn6mdmvp45580000gn/T/ipykernel_18157/109557609.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   terms_df_orig.replace('--',numpy.nan,inplace=True)

# %%
owners_df_orig = spreadsheet.worksheet('title', 'Terminal operators/owners (1/3)').get_as_df(start='A2')
owners_df_orig = owners_df_orig.loc[owners_df_orig.ComboID!='']
owners_df_orig = owners_df_orig.loc[owners_df_orig.Wiki!='']
owners_df = owners_df_orig.replace('',numpy.nan)

owner_parent_links_df = spreadsheet.worksheet('title', 'Owner–parent relationships (2/3)').get_as_df()
# only keep the owners with a checked relationship
#owner_parent_links_df = owner_parent_links_df.loc[owner_parent_links_df['Parent–Owner Relationship Checked?']=='yes']
owner_parent_links_df.replace('',numpy.nan,inplace=True)

parents_df = spreadsheet.worksheet('title', 'Parent metadata (3/3)').get_as_df(start='A2')
parents_df = parents_df.loc[parents_df.Parent!='']

owners_df.set_index('ComboID', inplace=True)
owner_parent_links_df.set_index('Owner', inplace=True)
parents_df.set_index('Parent', inplace=True)

# ****************************************

## create list of owner and parent column names
owner_pct_col_names = []
owner_col_names = []

parent_pct_col_names = []
parent_col_names = []

for num in range(1,10+1):
    owner_pct_col = f'Owner{num}%'
    owner_pct_col_names.append(owner_pct_col)
    
    owner_col = f'Owner{num}'
    owner_col_names.append(owner_col)
    
    parent_pct_col = f'Parent{num}%'
    parent_pct_col_names.append(parent_pct_col)
    
    parent_col = f'Parent{num}'
    parent_col_names.append(parent_col)

# ****************************************
# when there's a QCC owner and NO entry in Owner 1 column, fill with QCC info
qcc_owners_df = owners_df.loc[#(owners_df.Country=='China')&
                              (~owners_df['QCCOwner(业主单位)'].isnull())& # where QCCOwner col has entry
                              (owners_df['Owner1'].isnull())]#& # and where there's no Owner1 entry
                              #(~owners_df['QCCOwner(业主单位)'].isin(owner_parent_links_df.index))]

owners_df.loc[qcc_owners_df.index,'Owner1'] = qcc_owners_df['QCCOwner(业主单位)']
owners_df.loc[qcc_owners_df.index,'Owner1%'] = '100.00%'

# ****************************************
## fill in missing parent info by borrowing owner info
owners_FULL_set = owners_df[owner_col_names].stack().dropna().unique().tolist() # from owners_df
owners_researched_set = list(set(owner_parent_links_df.index.to_list()))#+['Unknown'] # only existing owners, plus 'Unknown'
owners_diff = list(set(owners_FULL_set)-set(owners_researched_set))
owners_diff.append('unknown') # just in case there's no "unknown" owners explicitly listed in database

# update owner_parent_links_df with these extra owners
owner_parent_links_df = pandas.concat([owner_parent_links_df, pandas.DataFrame(index=owners_diff, columns=owner_parent_links_df.columns)])
owner_parent_links_df['Parent1'].loc[owners_diff] = owners_diff
owner_parent_links_df['Parent1%'].loc[owners_diff] = '100.00%'

# ****************************************
# update parents_df with these as well
# note countries will be unknown...
parents_set = list(set(parents_df.index.to_list()))
parents_diff = list(set(owners_FULL_set)-set(parents_set)) # these are the cells highlighted in red
#parents_diff = list(set(owners_diff)-set((parents_set)) # works ok
parents_df = pandas.concat([parents_df, pandas.DataFrame(numpy.nan, index=parents_diff, columns=parents_df.columns)])
parents_df.replace(numpy.nan, 'unknown', inplace=True)
# Out:
# /var/folders/fl/t07mc8053p33mn6mdmvp45580000gn/T/ipykernel_18157/2707436492.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   owners_df = owners_df_orig.replace('',numpy.nan)
# /var/folders/fl/t07mc8053p33mn6mdmvp45580000gn/T/ipykernel_18157/2707436492.py:9: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   owner_parent_links_df.replace('',numpy.nan,inplace=True)
# /var/folders/fl/t07mc8053p33mn6mdmvp45580000gn/T/ipykernel_18157/2707436492.py:59: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   owner_parent_links_df['Parent1'].loc[owners_diff] = owners_diff
# /var/folders/fl/t07mc8053p33mn6mdmvp45580000gn/T/ipykernel_18157/2707436492.py:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   owner_parent_links_df['Parent1%'].loc[owners_diff] = '100.00%'

# %% [markdown]
# ## are there any comboids in the terminals sheet NOT in the operators/owners sheet?

# %%
for i in list(set(terms_df_orig.loc[terms_df_orig.Wiki!=''].ComboID.unique())-set(owners_df_orig.loc[owners_df_orig.Wiki!=''].ComboID.unique())):
    print(i)

# %% [markdown]
# things to probably delete in owners sheet:

# %%
set(owners_df.index.unique())-set(terms_df_orig.ComboID.unique())
# Out:
# set()

# %% [raw]
# parents_df.loc[parents_df.index.duplicated()]

# %% [raw]
# parents_df.loc['台灣中油天然氣事業部']

# %% [raw]
# owner_parent_links_df.loc['台灣中油天然氣事業部']

# %%
comboid_list = list(set(owners_df.index.to_list()))

# %% [markdown]
# # make dictionary to house parent info

# %%
po_dict = {}

# iterate through owners_df
# store in the big po_dict

#for combo_id,row in list(owners_df.loc[['T042001']].iterrows()):
for combo_id,row in list(owners_df.iterrows()):
    po_dict[combo_id] = {}
    
    owner_list_drop_nans = row[owner_col_names].dropna().tolist()
    owner_pct_vals = list(row[owner_pct_col_names].str.strip('%').astype('float').array/100.)[:owner_list_drop_nans.__len__()]

    #print(owner_list_drop_nans)
    # now go through the owner list, if it's empty create an uknown
    # if not empty, for each owner:
    #    save its percent ownership (make sure it's nan if it doesn't exist)
    #    save its list of parents (EVERY OWNER has a parent in the database)
    #    save the list of parent ownership (make sure it's a list of nans that is same length as list of parents)
    
    if owner_list_drop_nans==[]:
        owner='unknown'
        parent='unknown'
        owner_list = [owner] #+ [numpy.nan]*(owner_col_names.__len__()-1)
        parent_list = [parent] #+ [numpy.nan]*(parent_col_names.__len__()-1)
        owner_pct_vals = [numpy.nan]#*owner_pct_col_names.__len__()
        parent_pct_vals = [numpy.nan]#*parent_pct_col_names.__len__()
        
        # if there are no owners/parents, make them Unknown/Unknown
        po_dict[combo_id]['owner_parent_links'] = {}
        po_dict[combo_id]['owner_list'] = owner_list
        po_dict[combo_id]['owner_pct_vals'] = owner_pct_vals
        po_dict[combo_id]['owner_parent_links'][owner] = {}
        po_dict[combo_id]['owner_parent_links'][owner]['owner_pct_val'] = owner_pct_vals[0] # record the specific fraction val of the owner
        
        po_dict[combo_id]['owner_parent_links'][owner]['parent_list'] = parent_list
        po_dict[combo_id]['owner_parent_links'][owner]['parent_pct_vals'] = parent_pct_vals
        po_dict[combo_id]['owner_parent_links'][owner]['parent_hq_country_list'] = ['unknown']
    
    else:
        po_dict[combo_id]['owner_parent_links'] = {}
        print(owner_list_drop_nans)
        for o_idx,owner in enumerate(owner_list_drop_nans):
            parent_list_drop_nans = owner_parent_links_df.loc[owner][parent_col_names].squeeze().dropna().tolist()
            parent_pct_vals = list(owner_parent_links_df.loc[owner][parent_pct_col_names].str.strip('%').astype('float').array/100.)[:parent_list_drop_nans.__len__()] # only as long as parent_list

            po_dict[combo_id]['owner_list'] = owner_list_drop_nans
            po_dict[combo_id]['owner_pct_vals'] = owner_pct_vals
            
            po_dict[combo_id]['owner_parent_links'][owner] = {}
            po_dict[combo_id]['owner_parent_links'][owner]['owner_pct_val'] = owner_pct_vals[o_idx]
            
            po_dict[combo_id]['owner_parent_links'][owner]['parent_list'] = parent_list_drop_nans
            po_dict[combo_id]['owner_parent_links'][owner]['parent_pct_vals'] = parent_pct_vals
            
            po_dict[combo_id]['owner_parent_links'][owner]['parent_hq_country_list'] = parents_df.loc[parent_list_drop_nans].ParentHQCountry.tolist()
# Out:
# ['Fourchon LNG LLC']
# ['Fourchon LNG LLC']
# ['Alaska Gasline Development Corporation']
# ['Alaska Gasline Development Corporation']
# ['Alaska Gasline Development Corporation']
# ['Alturas LLC']
# ['Fortress Investment Group']
# ['American LNG Marketing LLC']
# ['Annova LNG']
# ['Annova LNG']
# ['Annova LNG']
# ['Annova LNG']
# ['Annova LNG']
# ['Annova LNG']
# ['Venture Global Calcasieu Pass']
# ['Venture Global Calcasieu Pass']
# ['Venture Global Calcasieu Pass']
# ['Venture Global Calcasieu Pass']
# ['Venture Global Calcasieu Pass']
# ['Venture Global Calcasieu Pass']
# ['Venture Global Calcasieu Pass']
# ['Venture Global Calcasieu Pass']
# ['Venture Global Calcasieu Pass']
# ['Venture Global Calcasieu Pass']
# ['Venture Global Calcasieu Pass']
# ['Venture Global Calcasieu Pass']
# ['Venture Global Calcasieu Pass']
# ['Venture Global Calcasieu Pass']
# ['Venture Global Calcasieu Pass']
# ['Venture Global Calcasieu Pass']
# ['Venture Global Calcasieu Pass']
# ['Venture Global Calcasieu Pass']
# ['CE FLNG LLC']
# ['CE FLNG LLC']
# ['Cameron LNG LLC']
# ['Cameron LNG LLC']
# ['Cameron LNG LLC']
# ['Cameron LNG LLC']
# ['Cameron LNG LLC']
# ['Cameron LNG LLC']
# ['Cameron LNG LLC']
# ['Commonwealth LNG']
# ['Commonwealth LNG']
# ['Commonwealth LNG']
# ['Commonwealth LNG']
# ['Commonwealth LNG']
# ['Commonwealth LNG']
# ['Corpus Christi Liquefaction LLC']
# ['Corpus Christi Liquefaction LLC']
# ['Corpus Christi Liquefaction LLC']
# ['Corpus Christi Liquefaction Stage III, LLC']
# ['Corpus Christi Liquefaction Stage III, LLC']
# ['Corpus Christi Liquefaction Stage III, LLC']
# ['Corpus Christi Liquefaction Stage III, LLC']
# ['Corpus Christi Liquefaction Stage III, LLC']
# ['Corpus Christi Liquefaction Stage III, LLC']
# ['Corpus Christi Liquefaction Stage III, LLC']
# ['Cheniere Energy']
# ['Cheniere Energy']
# ['Cove Point LNG, LP']
# ['Cove Point LNG, LP']
# ['Delfin LNG LLC']
# ['Delfin LNG LLC']
# ['Delfin LNG LLC']
# ['Delfin LNG LLC']
# ['Driftwood LNG LLC']
# ['Driftwood LNG LLC']
# ['Eagle LNG Partners Jacksonville LLC']
# ['Eagle LNG Partners Jacksonville LLC']
# ['Eagle LNG Partners Jacksonville LLC']
# ['Eagle LNG Partners Jacksonville LLC']
# ['Southern LNG Company LLC']
# ['Southern LNG Company LLC']
# ['Southern LNG Company LLC']
# ['Southern LNG Company LLC']
# ['Southern LNG Company LLC']
# ['Southern LNG Company LLC']
# ['Southern LNG Company LLC']
# ['Southern LNG Company LLC']
# ['Southern LNG Company LLC']
# ['Southern LNG Company LLC']
# ['Southern LNG Company LLC']
# ['Southern LNG Company LLC']
# ['Eos LNG LLC']
# ['Floridian Natural Gas Storage Company LLC']
# ['Freeport LNG Development']
# ['Freeport LNG Liquefaction, LLC']
# ['Freeport LNG Liquefaction 2, LLC']
# ['Freeport LNG Liquefaction 3, LLC']
# ['Freeport LNG Development']
# ['Freeport LNG Liquefaction, LLC']
# ['G2 Net-Zero LNG LLC']
# ['G2 Net-Zero LNG LLC']
# ['G2 Net-Zero LNG LLC']
# ['G2 Net-Zero LNG LLC']
# ['G2 Net-Zero LNG LLC']
# ['G2 Net-Zero LNG LLC']
# ['G2 Net-Zero LNG LLC']
# ['G2 Net-Zero LNG LLC']
# ['G2 Net-Zero LNG LLC']
# ['G2 Net-Zero LNG LLC']
# ['QatarEnergy', 'ExxonMobil']
# ['Golden Pass LNG Terminal LLC']
# ['Golden Pass LNG Terminal LLC']
# ['Golden Pass LNG Terminal LLC']
# ['Gulf LNG Liquefaction Company, LLC']
# ['Gulf LNG Liquefaction Company, LLC']
# ['Gulf LNG Liquefaction Company, LLC']
# ['Moda Midstream LLC']
# ['Jordan Cove LNG']
# ['Jordan Cove LNG']
# ['Jordan Cove LNG']
# ['Jordan Cove LNG']
# ['Jordan Cove LNG']
# ['Trans-Foreland Pipeline Co LLC']
# ['Trans-Foreland Pipeline Co LLC']
# ['Lake Charles LNG Company, LLC']
# ['Lake Charles LNG Company, LLC', 'Lake Charles LNG Export Company, LLC']
# ['Lake Charles LNG Company, LLC', 'Lake Charles LNG Export Company, LLC']
# ['Lake Charles LNG Company, LLC', 'Lake Charles LNG Export Company, LLC']
# ['Louisiana LNG Energy LLC']
# ['Louisiana LNG Energy LLC']
# ['Magnolia LNG Holdings']
# ['Magnolia LNG Holdings']
# ['Magnolia LNG Holdings']
# ['Magnolia LNG Holdings']
# ['SCT&E LNG LLC']
# ['SCT&E LNG LLC']
# ['SCT&E LNG LLC']
# ['SCT&E LNG LLC']
# ['SCT&E LNG LLC']
# ['SCT&E LNG LLC']
# ['Lloyds Energy Group LLC']
# ['Lloyds Energy Group LLC']
# ['Port Arthur LNG Phase I, LLC', 'PALNG Common Facilities Company, LLC']
# ['Port Arthur LNG Phase I, LLC', 'PALNG Common Facilities Company, LLC']
# ['Port Arthur LNG Phase II, LLC', 'PALNG Common Facilities Company, LLC']
# ['Port Arthur LNG Phase II, LLC', 'PALNG Common Facilities Company, LLC']
# ['Texas LNG Brownsville, LLC']
# ['Texas LNG Brownsville, LLC']
# ['Rio Grande LNG LLC']
# ['Rio Grande LNG LLC']
# ['Rio Grande LNG LLC']
# ['Rio Grande LNG LLC']
# ['Rio Grande LNG LLC']
# ['Rio Grande LNG LLC']
# ['Sabine Pass LNG']
# ['Sabine Pass Liquefaction']
# ['Sabine Pass Liquefaction']
# ['Sabine Pass Liquefaction']
# ['Sabine Pass Liquefaction']
# ['Sabine Pass Liquefaction']
# ['Sabine Pass Liquefaction']
# ['Sabine Pass Liquefaction']
# ['Strom Inc']
# ['Venture Global Plaquemines LNG, LLC']
# ['Venture Global Plaquemines LNG, LLC']
# ['Sonatrach']
# ['Sonatrach']
# ['Sonatrach']
# ['Sonatrach']
# ['Sonatrach']
# ['Sonatrach']
# ['Sonatrach']
# ['Sonatrach']
# ['Sonatrach']
# ['Sonatrach']
# ['Sonatrach']
# ['Sonatrach']
# ['Sonatrach']
# ['Sonatrach']
# ['Sonatrach']
# ['Sonatrach']
# ['Sonatrach']
# ['Sonatrach']
# ['Sonatrach']
# ['Sonatrach']
# ['Sonatrach']
# ['Angola LNG']
# ['Gasol', 'SOCAR Trading']
# ['Golar LNG', 'Keppel Corporation Ltd ', 'Black & Veatch Holding Company']
# ['Golar LNG', 'Keppel Corporation Ltd ', 'Black & Veatch Holding Company']
# ['Golar LNG', 'Keppel Corporation Ltd ', 'Black & Veatch Holding Company']
# ['Golar LNG', 'Keppel Corporation Ltd ', 'Black & Veatch Holding Company']
# ['Engie', 'Société Nationale des Hydrocarbures']
# ['SEGAS']
# ['SEGAS']
# ['El Beheira Natural Gas Liquefaction Company']
# ['Idku Natural Gas Liquefaction Company']
# ['Ophir Energy', 'Golar LNG', 'Schlumberger']
# ['Ophir Energy', 'Golar LNG', 'Schlumberger']
# ['Ophir Energy', 'Golar LNG', 'Schlumberger']
# ['EG LNG']
# ['EG LNG']
# ['Tema LNG Terminal Company']
# ['Kenya Ministry Of Energy And Petroleum']
# ['Sirte Oil Company']
# ['Sirte Oil Company']
# ['Sirte Oil Company']
# ['Sirte Oil Company']
# ['Office National de l’Electricite et de l’Eau Potable']
# ['TotalEnergies', 'Mitsui Group', 'ENH', 'ONGC', 'Bharat PetroResources', 'Oil India', 'PTTEP']
# ['TotalEnergies', 'Mitsui Group', 'ENH', 'ONGC', 'Bharat PetroResources', 'Oil India', 'PTTEP']
# ['TotalEnergies', 'Mitsui Group', 'ENH', 'ONGC', 'Bharat PetroResources', 'Oil India', 'PTTEP']
# ['TotalEnergies', 'Mitsui Group', 'ENH', 'ONGC', 'Bharat PetroResources', 'Oil India', 'PTTEP']
# ['Coral South LNG']
# ['Nigeria LNG']
# ['Nigeria LNG']
# ['Nigeria LNG']
# ['Nigeria LNG']
# ['Nigeria LNG']
# ['Nigeria LNG']
# ['Nigeria LNG']
# ['Nigeria LNG']
# ['Nigeria LNG']
# ['Nigeria LNG']
# ['Nigeria LNG']
# ['Nigeria LNG']
# ['Nigeria LNG']
# ['Brass LNG Ltd']
# ['Brass LNG Ltd']
# ['Nigerian National Petroleum Corporation']
# ['Nigerian National Petroleum Corporation']
# ['Nigerian National Petroleum Corporation']
# ['Nigerian National Petroleum Corporation']
# ['Tanzania Petroleum Development Corporation', 'Equinor', 'Shell', 'ExxonMobil', 'Pavilion Energy', 'MedcoEnergi']
# ['Tanzania Petroleum Development Corporation', 'Equinor', 'Shell', 'ExxonMobil', 'Pavilion Energy', 'MedcoEnergi']
# ['PetroSA']
# ['Karpowership']
# ['Karpowership']
# ['Karpowership']
# ['Petronet LNG']
# ['Reliance Industries Limited']
# ['Petrobangla']
# ['Summit Oil and Shipping Co Ltd', 'Mitsubishi']
# ['Government of Brunei', 'Shell', 'Mitsubishi']
# ['Government of Brunei', 'Shell', 'Mitsubishi']
# ['Government of Brunei', 'Shell', 'Mitsubishi']
# ['Government of Brunei', 'Shell', 'Mitsubishi']
# ['Government of Brunei', 'Shell', 'Mitsubishi']
# ['INPEX Masela Ltd']
# ['PT Perta Arun Gas']
# ['Pertamina', 'ExxonMobil', 'PT Japan Indonesia LNG Co (JILCO)']
# ['Pertamina', 'ExxonMobil', 'PT Japan Indonesia LNG Co (JILCO)']
# ['Pertamina', 'ExxonMobil', 'PT Japan Indonesia LNG Co (JILCO)']
# ['Pertamina', 'ExxonMobil', 'PT Japan Indonesia LNG Co (JILCO)']
# ['Pertamina', 'ExxonMobil', 'PT Japan Indonesia LNG Co (JILCO)']
# ['Pertamina', 'ExxonMobil', 'PT Japan Indonesia LNG Co (JILCO)']
# ['PT Pelindo']
# ['Pertamina', 'Kalla Group']
# ['Government of Indonesia']
# ['Government of Indonesia']
# ['Government of Indonesia']
# ['Government of Indonesia']
# ['Government of Indonesia']
# ['Government of Indonesia']
# ['Government of Indonesia']
# ['Government of Indonesia']
# ['Government of Indonesia']
# ['Pertamina']
# ['Jawa Satu Regas']
# ['PT Donggi-Senoro LNG']
# ['Pertamina']
# ['PT Nusantara Regas']
# ['PT South Sulawesi LNG']
# ['PT South Sulawesi LNG']
# ['PT South Sulawesi LNG']
# ['PT South Sulawesi LNG']
# ['BP Berau Ltd', 'MI Berau', 'CNOOC Muturi', 'Nippon Oil Exploration', 'KG Berau Petroleum', 'Indonesia Natural Gas Resources Muturi', 'KG Wiriagar Petroleum']
# ['BP Berau Ltd', 'MI Berau', 'CNOOC Muturi', 'Nippon Oil Exploration', 'KG Berau Petroleum', 'Indonesia Natural Gas Resources Muturi', 'KG Wiriagar Petroleum']
# ['BP Berau Ltd', 'MI Berau', 'CNOOC Muturi', 'Nippon Oil Exploration', 'KG Berau Petroleum', 'Indonesia Natural Gas Resources Muturi', 'KG Wiriagar Petroleum']
# ['Petronas', 'Sabah Energy']
# ['Petronas']
# ['Petronas']
# ['Petronas']
# ['Petronas', 'Dialog Group Berhad', 'Government of Johor']
# ['Petronas', 'Mitsubishi', 'Government of Sarawak']
# ['Petronas', 'Mitsubishi', 'Government of Sarawak']
# ['Petronas', 'Mitsubishi', 'Government of Sarawak']
# ['Petronas', 'ENEOS Corporation', 'Government of Sarawak', 'PTT']
# ['Petronas', 'Mitsubishi', 'Government of Sarawak']
# ['Petronas', 'Mitsubishi', 'Government of Sarawak']
# ['Petronas', 'Mitsubishi', 'Government of Sarawak']
# ['Petronas', 'Government of Sarawak', 'PTT', 'Diamond Gas']
# ['Petronas', 'Government of Sarawak', 'PTT', 'Diamond Gas']
# ['4Gas']
# ['ETPL']
# ['ETPL']
# ['Pakistan GasPort Consortium Limited']
# ['Daewoo Gas']
# ['ExxonMobil', 'Pacific LNG Operations']
# ['TotalEnergies', 'ExxonMobil', 'Santos', 'JX Nippon Oil & Gas Exploration']
# ['TotalEnergies', 'ExxonMobil', 'Santos', 'JX Nippon Oil & Gas Exploration']
# ['TotalEnergies', 'ExxonMobil', 'Santos', 'JX Nippon Oil & Gas Exploration']
# ['TotalEnergies', 'ExxonMobil', 'Santos', 'JX Nippon Oil & Gas Exploration']
# ['Kumal Petroleum Holdings Ltd']
# ['PNG LNG']
# ['PNG LNG']
# ['PNG LNG']
# ['Philippine National Oil Company']
# ['Philippine National Oil Company']
# ['Samat LNG Corporation']
# ['Energy World']
# ['Singapore LNG Corporation']
# ['Singapore LNG Corporation']
# ['Singapore LNG Corporation']
# ['GS Group', 'SK Group']
# ['POSCO']
# ['KOGAS']
# ['KOGAS']
# ['KOGAS']
# ['KOGAS']
# ['Petronet LNG', 'Mitsubishi', 'Sojitz Corporation']
# ['CPC Corporation']
# ['CPC Corporation']
# ['CPC Corporation']
# ['CPC Corporation']
# ['CPC Corporation']
# ['CPC Corporation']
# ['CPC Corporation']
# ['CPC Corporation']
# ['CPC Corporation']
# ['PTT LNG']
# ['PTT LNG']
# ['PTT LNG']
# ['LNG Vietnam']
# ['LNG Vietnam']
# ['Cai Mep LNG']
# ['PetroVietnam Gas', 'AES Corporation']
# ['PetroVietnam Gas', 'AES Corporation']
# ['PetroChina Co Ltd', 'Shell']
# ['PetroChina Co Ltd', 'Shell']
# ['PetroChina Co Ltd', 'Shell']
# ['PetroChina Co Ltd', 'Shell']
# ['Origin Energy Limited', 'ConocoPhillips', 'Sinopec']
# ['Origin Energy Limited', 'ConocoPhillips', 'Sinopec']
# ['Santos', 'Engie']
# ['Woodside Energy', 'PetroChina Co Ltd', 'BP', 'Japan Australia LNG Pty Ltd']
# ['Woodside Energy', 'PetroChina Co Ltd', 'BP', 'Japan Australia LNG Pty Ltd']
# ['Leif Höegh & Co']
# ['Santos', 'SK E&S', 'INPEX', 'Eni', 'JERA', 'Tokyo Gas']
# ['Santos', 'SK E&S', 'INPEX', 'Eni', 'JERA', 'Tokyo Gas']
# ['Liquefied Natural Gas Limited']
# ['Liquefied Natural Gas Limited']
# ['Santos', 'Petronas', 'TotalEnergies', 'KOGAS']
# ['Santos', 'Petronas', 'TotalEnergies', 'KOGAS']
# ['Chevron Australia', 'ExxonMobil', 'Shell Australia', 'Osaka Gas', 'MidOcean Energy', 'JERA Australia']
# ['Chevron Australia', 'ExxonMobil', 'Shell Australia', 'Osaka Gas', 'MidOcean Energy', 'JERA Australia']
# ['Chevron Australia', 'ExxonMobil', 'Shell Australia', 'Osaka Gas', 'MidOcean Energy', 'JERA Australia']
# ['Chevron Australia', 'ExxonMobil Australia', 'Shell Australia', 'Osaka Gas Australia', 'MidOcean Energy', 'JERA Australia']
# ['INPEX', 'TotalEnergies', 'Osaka Gas', 'Toho Gas', 'CPC Corporation', 'Kansai Electric Power', 'JERA']
# ['INPEX', 'TotalEnergies', 'Osaka Gas', 'Toho Gas', 'CPC Corporation', 'Kansai Electric Power', 'JERA']
# ['Ichthys LNG Pty Ltd']
# ['Newcastle GasDock Company']
# ['BHP Group Limited', 'BP', 'Chevron', 'Japan Australia LNG Pty Ltd', 'Shell', 'Woodside Energy']
# ['BHP Group Limited', 'BP', 'Chevron', 'Japan Australia LNG Pty Ltd', 'Shell', 'Woodside Energy']
# ['BHP Group Limited', 'BP', 'Chevron', 'Japan Australia LNG Pty Ltd', 'Shell', 'Woodside Energy']
# ['BHP Group Limited', 'BP', 'Chevron', 'Japan Australia LNG Pty Ltd', 'Shell', 'Woodside Energy']
# ['BHP Group Limited', 'BP', 'Chevron', 'Japan Australia LNG Pty Ltd', 'Shell', 'Woodside Energy']
# ['Woodside Energy', 'MidOcean Energy', 'Kansai Electric Power']
# ['Woodside Burrup Train 2 A Pty Ltd', 'Global Infrastructure Partners']
# ['Woodside Energy', 'MidOcean Energy', 'Kansai Electric Power']
# ['Shell', 'INPEX', 'CPC Corporation', 'KOGAS']
# ['Shell', 'China National Offshore Oil Corp']
# ['Shell', 'MidOcean Energy']
# ['ExxonMobil', 'BHP Group Limited']
# ['Government of Timor-Leste', 'Woodside Energy', 'Osaka Gas']
# ['Melbana Energy']
# ['Chevron', 'Kuwait Foreign Petroleum Exploration Company', 'Woodside Energy', 'JOGMEC', 'Kyushu Electric Power', 'Mitsubishi', 'NYK', 'JERA']
# ['Chevron', 'Kuwait Foreign Petroleum Exploration Company', 'Woodside Energy', 'JOGMEC', 'Kyushu Electric Power', 'Mitsubishi', 'NYK', 'JERA']
# ['AC LNG']
# ['China National Offshore Oil Corp', 'INPEX', 'JGC Holdings Corporation']
# ['China National Offshore Oil Corp', 'INPEX', 'JGC Holdings Corporation']
# ['Bear Head Energy Inc']
# ['Bear Head Energy Inc']
# ['Bear Head Energy Inc']
# ['Bear Head Energy Inc']
# ['TC Energy', 'Petro-Canada']
# ['Repsol']
# ['Repsol', 'Irving Group of Companies']
# ['Repsol']
# ['Cedar LNG Partners LP']
# ['Rockyview Resources']
# ['Rockyview Resources']
# ['Rockyview Resources']
# ['Rockyview Resources']
# ['AltaGas', 'Idemitsu Kosan', 'Électricité de France', 'EXMAR Group']
# ['Pieridae Energy']
# ['Pieridae Energy']
# ['Woodside Energy']
# ['Woodside Energy']
# ['Chevron Canada', 'Woodside Energy']
# ['Chevron Canada', 'Woodside Energy']
# ['Chevron Canada', 'Woodside Energy']
# ['Kitsault Energy']
# ['Kitsault Energy']
# ['Kitsault Energy']
# ['Kitsault Energy']
# ['LNG Canada']
# ['LNG Canada']
# ['LNG Canada']
# ['LNG Canada']
# ['Steelhead LNG']
# ['NewTimes Energy']
# ['NewTimes Energy']
# ['NewTimes Energy']
# ["Government of Nisga'a Nation"]
# ['Orca LNG']
# ['Orca LNG']
# ['Orca LNG']
# ['Orca LNG']
# ['Orca LNG']
# ['Orca LNG']
# ['PNW LNG']
# ['PNW LNG']
# ['PNW LNG']
# ['Shell']
# ['Shell']
# ['Shell']
# ['Enbridge', 'Énergir', 'Engie', 'Gazprom']
# ['Steelhead LNG']
# ['Steelhead LNG']
# ['Steelhead LNG']
# ['Steelhead LNG']
# ['Canada Stewart Energy Group Ltd']
# ['Canada Stewart Energy Group Ltd']
# ['Canada Stewart Energy Group Ltd']
# ['Canada Stewart Energy Group Ltd']
# ['Canada Stewart Energy Group Ltd']
# ['Canada Stewart Energy Group Ltd']
# ['Stolt LNGaz JV']
# ['Stolt LNGaz JV']
# ['WestPac LNG Corporation']
# ['AltaGas', 'Idemitsu Kosan']
# ['Watson Island LNG Corporation']
# ['ExxonMobil', 'Imperial Oil Resources Ltd']
# ['ExxonMobil', 'Imperial Oil Resources Ltd']
# ['ExxonMobil', 'Imperial Oil Resources Ltd']
# ['ExxonMobil', 'Imperial Oil Resources Ltd']
# ['ExxonMobil', 'Imperial Oil Resources Ltd']
# ['ExxonMobil', 'Imperial Oil Resources Ltd']
# ['Woodfibre LNG Ltd']
# ['Hubei Energy', 'Great United Petroleum Company']
# ['Guangdong Huafeng Zhongtian LNG Co Ltd']
# ['Guangdong Huafeng Zhongtian LNG Co Ltd']
# ['China Huadian Group Corp']
# ['National Pipe Network Group Dalian LNG Co Ltd']
# ['National Pipeline Network Group Guangxi Fangchenggang Natural Gas Co Ltd']
# ['National Pipeline Network Group Guangxi Fangchenggang Natural Gas Co Ltd']
# ['CNOOC -FUJIAN LNG Co Ltd']
# ['CNOOC -FUJIAN LNG Co Ltd']
# ['PetroChina Kunlun Gas Co Ltd Fujian Branch']
# ['Jiangsu Huadian Ganyu LNG Co Ltd']
# ['GUANG DONG DAPENG LNG Co Ltd']
# ['GUANG DONG DAPENG LNG Co Ltd']
# ['National Pipe Network Group Beihai LNG Co Ltd']
# ['National Pipe Network Group Beihai LNG Co Ltd']
# ['Guangxi Gas Group Co Ltd']
# ['CNOOC Hainan Gas Co Ltd']
# ['CNOOC Hainan Gas Co Ltd']
# ['Hong Kong LNG Terminal Co Ltd']
# ['JOVO LNG Storage and Transportation Co.,ltd.dongguan']
# ['Guangdong Guanghaiwan Energy Holdings Co Ltd']
# ['Guangdong Guanghaiwan Energy Holdings Co Ltd']
# ['PetroChina Jiangsu LNG Co Ltd']
# ['PetroChina Jiangsu LNG Co Ltd']
# ['PetroChina Jiangsu LNG Co Ltd']
# ['PetroChina Jiangsu LNG Co Ltd']
# ['Ningxia Hanas LNG Co Ltd']
# ['Jiangsu Honghai Energy Co Ltd']
# ['Pipechina Yuedong LNG Co Ltd']
# ['Chinese National Petroleum Corporation']
# ['Shandong Penglai Baota Yina Natural Gas Co Ltd']
# ['Putian Hanas Liquefied Natural Gas Co Ltd']
# ['Putian Hanas Liquefied Natural Gas Co Ltd']
# ['Guanghui ENERGY Comprehensive Logistics Development Co Ltd']
# ['Guanghui ENERGY Comprehensive Logistics Development Co Ltd']
# ['Guanghui ENERGY Comprehensive Logistics Development Co Ltd']
# ['Guanghui ENERGY Comprehensive Logistics Development Co Ltd']
# ['China National Petroleum Corporation']
# ['Pacific Energy']
# ['Ningxia Hanas LNG Co Ltd']
# ['Lanqiao Group', 'Beijing Energy Group']
# ['GCL Huidong LNG Rudong Co Ltd']
# ['Sinopec Qingdao LNG Co Ltd']
# ['Sinopec Qingdao LNG Co Ltd']
# ['Sinopec Qingdao LNG Co Ltd']
# ['Shanghai LNG Co Ltd']
# ['Shanghai LNG Co Ltd']
# ['Shenergy Yangshan LNG Co Ltd']
# ['Guangdong Yuedian Shantou LNG Co Ltd']
# ['Cnooc Shenzhen Gas Co Ltd']
# ['National Oil and Gas Pipeline Network Group Co Ltd Shenzhen LNG Project Management Department']
# ['Petrochina Jingtang Lng Co Ltd']
# ['Petrochina Jingtang Lng Co Ltd']
# ['CNOOC Tianjin LNG Limited Co']
# ['CNOOC Tianjin LNG Limited Co']
# ['CNOOC Tianjin LNG Limited Co']
# ['Sinopec Tianjin LNG Co Ltd']
# ['Sinopec Tianjin LNG Co Ltd']
# ['Sinopec Tianjin LNG Co Ltd']
# ['Zhejiang Zheneng Wenzhou LNG Co Ltd']
# ['CNOOC Gas & Power Group']
# ['Maoming Bohe LNG Co Ltd']
# ['Shanghai Natural Gas Pipeline Network Co Ltd']
# ['Anhui Changjiang LNG Co Ltd']
# ['CNOOC Gas and Power Group Jiangsu Natural Gas Co Ltd']
# ['CNOOC Gas and Power Group Jiangsu Natural Gas Co Ltd']
# ['Shandong Poly GCL Huanya International Energy Co Ltd']
# ['Shandong Poly GCL Huanya International Energy Co Ltd']
# ['Zhongjiao Yingkou Liquefied Natural Gas Co Ltd']
# ['PipeChina Fujian Investment Natural Gas Co Ltd']
# ['CNOOC Zhejiang Ningbo LNG Co Ltd']
# ['CNOOC Zhejiang Ningbo LNG Co Ltd']
# ['CNOOC Green Energy Port Zhejiang Ningbo Energy Co Ltd']
# ['ENN (Zhoushan) LNG Co Ltd']
# ['ENN (Zhoushan) LNG Co Ltd']
# ['ENN (Zhoushan) LNG Co Ltd']
# ['Ningxia Hanas LNG Co Ltd']
# ['Guangdong Zhuhai GOLDEN Bay LNG Ltd']
# ['Guangdong Zhuhai GOLDEN Bay LNG Ltd']
# ['Gruppo Falcione']
# ['Fluxys']
# ['Fluxys']
# ['Fluxys']
# ['Petronet LNG']
# ['Petronet LNG']
# ['Petronet LNG']
# ['E.ON', 'OMV', 'TotalEnergies', 'RWE', 'Geoplin']
# ['Konkan LNG Ltd']
# ['Konkan LNG Ltd']
# ['Konkan LNG Ltd']
# ['HEP Grupa', 'Plinacro']
# ['HEP Grupa', 'Plinacro']
# ['LNG Croatia LLC']
# ['Dhamra LNG Terminal Pvt Ltd']
# ['LNG Croatia LLC']
# ['ETYFA']
# ['DEFA']
# ['DEFA']
# ['DEFA']
# ['DEFA']
# ['DEFA']
# ['DEFA']
# ['DEFA']
# ['DEFA']
# ['Petronet LNG']
# ['Alexela']
# ['Essar Ports']
# ['Vopak', 'Port of Tallinn']
# ['H-Energy']
# ['Hamina Energy', 'Alexela', 'Wärtsilä']
# ['Shell Energy India Pvt Ltd']
# ['Shell Energy India Pvt Ltd']
# ['Gasum']
# ['Essar Group']
# ['Gasum']
# ['Western Concessions Private Limited']
# ['Western Concessions Private Limited']
# ['Manga Terminal Oy']
# ['APGDC']
# ['Dunkerque LNG']
# ['Dunkerque LNG']
# ['Petronet LNG']
# ['Engie']
# ['Engie']
# ['Engie']
# ['Krishna Godavari LNG Terminal Pvt Ltd']
# ['Vopak', 'Shell']
# ['New Mangalore Port Trust']
# ['Engie']
# ['Fox Petroleum']
# ['Gaz de Normandie']
# ['Gujarat State Petronet', 'S.B. Adani Family Trust']
# ['Engie']
# ['Engie']
# ['Swan Energy Limited', 'Indian Farmers Fertilizers Cooperative', 'Mitsui Group', 'Gujarat Maritime Board', 'Gujarat State Petronet']
# ['Swan Energy Limited', 'Indian Farmers Fertilizers Cooperative', 'Mitsui Group', 'Gujarat Maritime Board', 'Gujarat State Petronet']
# ['Uniper']
# ['JERA', 'Toho Gas']
# ['German LNG Terminal']
# ['Chubu Electric Power', 'Toho Gas', 'Chita LNG Co Ltd']
# ['DESFA']
# ['Toho Gas']
# ['New Fortress Energy']
# ['Saibu Gas']
# ['ExxonMobil', 'QatarEnergy', 'Cassa Depositi e Prestiti']
# ['JERA']
# ['Brindisi LNG SpA']
# ['JXTG Holdings']
# ['Api Nova Energia']
# ['Hokkaido Gas']
# ['LNG Medgas Terminal srl', 'Sorgenia']
# ['Hiroshima Gas']
# ['OLT Offshore LNG Toscana']
# ['OLT Offshore LNG Toscana']
# ['Saibu Gas', 'Kyushu Electric Power']
# ['Saibu Gas', 'Kyushu Electric Power']
# ['GNL Italia Spa']
# ['Snam']
# ['Tohoku Electric Power', 'Nihonkai LNG']
# ['Nuove Energie']
# ['JERA']
# ['Tokyo Electric Power Company']
# ['Shell']
# ['Kansai Electric Power']
# ['E.ON']
# ['Osaka Gas']
# ['Naturgy']
# ['Tokyo Gas']
# ['Tokyo Gas']
# ['Latvenergo']
# ['Latvenergo']
# ['Hokkaido Gas']
# ['KN Energies']
# ['KN Energies']
# ['JERA']
# ['Armada LNG Mediterrana']
# ['Nippon Gas']
# ['Gasunie', 'Vopak']
# ['Gasunie', 'Vopak']
# ['JERA']
# ['Equinor', 'Petoro', 'TotalEnergies', 'Neptune Energy', 'Wintershall DEA']
# ['JXTG Holdings']
# ['North Sea Midstream Partners']
# ['JXTG Holdings']
# ['PKN Orlen']
# ['PKN Orlen']
# ['Polskie LNG SA']
# ['Saibu Gas']
# ['REN Atlantico']
# ['Okinawa Electric Power']
# ['RomGaz']
# ['JERA', 'Tokyo Gas']
# ['RusKhimAlyans']
# ['RusKhimAlyans']
# ['RusKhimAlyans']
# ['INPEX']
# ['SC Sakhalinmorneftegaz-Shelf', 'JSC RN-Astra', 'SODECO', 'ONGC']
# ['SC Sakhalinmorneftegaz-Shelf', 'JSC RN-Astra', 'SODECO', 'ONGC']
# ['Tokyo Gas']
# ['Oita LNG']
# ['Alltech Group', 'Rosneft']
# ['Kansai Electric Power']
# ['Sakhalin Energy LLC']
# ['Sakhalin Energy LLC']
# ['Sakhalin Energy LLC']
# ['Sakaide LNG']
# ['Gazprom']
# ['Osaka Gas']
# ['Osaka Gas']
# ['Yamal LNG']
# ['Yamal LNG']
# ['Yamal LNG']
# ['Yamal LNG']
# ['City of Sendai Gas Bureau']
# ['OOO Arctic LNG 2']
# ['OOO Arctic LNG 2']
# ['OOO Arctic LNG 2']
# ['Tohoku Electric Power']
# ['Enagás']
# ['JERA', 'Tokyo Gas']
# ['Enagás', 'Basque Energy Board (EVE)']
# ['Shizuoka Gas', 'ENEOS Corporation']
# ['Enagás']
# ['Japex']
# ['Enagás', 'Reganosa']
# ['Kitakyushu LNG', 'Kyushu Electric Power', 'Nippon Steel Corporation']
# ['Enagás']
# ['Chugoku Electric Power']
# ['Enagás']
# ['Toho Gas']
# ['Reganosa']
# ['Endesa', 'Gas Natural Fenosa', 'Tojeiro Group', 'NovaCaixaGalicia', 'Sonatrach', 'Government of Galicia', 'Santander Bank']
# ['Infraestructuras de Gas', 'Iniciativas de Gas']
# ['Enagás']
# ['ENARSA', 'YPF']
# ['EXMAR Group']
# ['AGA Gas']
# ['YPF', 'Corporación America International']
# ['Kolin Insaat', 'Kalyon Holding AS']
# ['UTE Escobar']
# ['EgeGaz AS']
# ['AES Corporation']
# ['BOTAŞ']
# ['Petrobras']
# ['Canatxx LNG Limited']
# ['Petrobras']
# ['Calor', 'Osaka Gas', 'Sojitz Corporation', 'Sumitomo Corporation']
# ['Petrobras', 'BG Group', 'Galp', 'Repsol']
# ['Shell', 'Ancala Partners']
# ['Colbún S.A.', 'AES Andes']
# ['National Grid']
# ['Grain LNG']
# ['GasAtacama']
# ['Harland & Wolff Group Holdings plc']
# ['Engie', 'Ameris Capital']
# ['QatarEnergy', 'ExxonMobil', 'TotalEnergies']
# ['QatarEnergy', 'ExxonMobil', 'TotalEnergies']
# ['Biobiogenera', 'Cheniere Energy']
# ['Trafigura']
# ['Trafigura']
# ['Fluxys', 'EIG Global Energy Partners', 'ENAP']
# ['Fluxys', 'EIG Global Energy Partners', 'ENAP']
# ['Government of Ukraine']
# ['Sociedad Portuaria El Cayao (SPEC)']
# ['Sociedad Portuaria El Cayao (SPEC)']
# ['Sociedad Portuaria El Cayao (SPEC)']
# ['EXMAR Group']
# ['IAHL Corporation']
# ['AES Corporation', 'AFI Popular', 'Grupo Linda', 'Grupo Estrella']
# ['BW Group', 'InterEnergy Holdings']
# ['Invenergy', 'Grupo Calleja', 'VC Energy de Centroamerica', 'Quantum Capital Group']
# ['Vopak', 'Enagás']
# ['Repsol']
# ['KOGAS', 'Mitsui Group', 'Samsung']
# ['KOGAS']
# ['AES Corporation', 'Grupo Linda', 'Grupo Estrella']
# ['Hunt Oil Company', 'Shell', 'MidOcean Energy', 'Marubeni Corporation']
# ['Excelerate Energy']
# ['Naturgy', 'Engie', 'Mitsui Group', 'OCO Partners']
# ['Shell', 'BP', 'NGC Trinidad and Tobago']
# ['Shell', 'BP']
# ['Shell', 'BP']
# ['Shell', 'BP', 'NGC Trinidad and Tobago']
# ['BP', 'BG Group', 'Repsol', 'NGC Trinidad and Tobago']
# ['Mitsui O.S.K. Lines']
# ['Bahrain LNG']
# ['National Iranian Oil Company', 'Saving, Welfare, & Pension Funds of Iran Petroleum Industry', 'Iran Petroleum Industry Pension Fund']
# ['National Iranian Oil Company', 'Saving, Welfare, & Pension Funds of Iran Petroleum Industry', 'Iran Petroleum Industry Pension Fund']
# ['QatarEnergy']
# ['QatarEnergy']
# ['QatarEnergy']
# ['QatarEnergy']
# ['MahTaab Parto Kangan LNG Co']
# ['National Iranian Gas Exports Company']
# ['National Iranian Gas Exports Company']
# ['EXMAR Group']
# ['Israel Natural Gas Pipelines Company', 'Eilat Ashkelon Pipeline Company']
# ['Israel Natural Gas Lines Ltd']
# ['Isramco', 'Chevron', 'NewMed Energy', 'Tamar Petroleum', 'Dor Gas Exploration LP', 'Everest Infrastructures LP']
# ['Jordan Ministry of Energy and Mineral Resources']
# ['Kuwait National Petroleum Company']
# ['Kuwait National Petroleum Company']
# ['Government of Oman', 'Shell', 'TotalEnergies', 'Korea LNG', 'Mitsubishi', 'Mitsui Group', 'PTTEP', 'Itochu Corporation']
# ['Government of Oman', 'Shell', 'TotalEnergies', 'Korea LNG', 'Mitsubishi', 'Mitsui Group', 'PTTEP', 'Itochu Corporation']
# ['Government of Oman', 'Oman LNG', 'Naturgy', 'Mitsubishi', 'Itochu Corporation', 'Osaka Gas']
# ['Government of Oman', 'Shell', 'TotalEnergies', 'Korea LNG', 'Mitsubishi', 'Mitsui Group', 'PTTEP', 'Itochu Corporation']
# ['QatarEnergy']
# ['QatarEnergy']
# ['QatarEnergy']
# ['QatarEnergy', 'ExxonMobil']
# ['QatarEnergy', 'ExxonMobil', 'TotalEnergies']
# ['QatarEnergy', 'ConocoPhillips', 'Mitsui Group']
# ['QatarEnergy', 'Shell']
# ['QatarEnergy', 'ExxonMobil', 'KOGAS', 'Itochu Corporation', 'LNG Japan Corporation']
# ['QatarEnergy', 'ExxonMobil', 'KOGAS', 'Itochu Corporation', 'LNG Japan Corporation']
# ['QatarEnergy', 'ExxonMobil', 'OPIC Middle East Natural Gas Corporation']
# ['QatarEnergy', 'ExxonMobil', 'OPIC Middle East Natural Gas Corporation']
# ['QatarEnergy', 'ExxonMobil', 'OPIC Middle East Natural Gas Corporation']
# ['QatarEnergy', 'ExxonMobil']
# ['QatarEnergy', 'ExxonMobil']
# ['ADNOC LNG']
# ['ADNOC LNG']
# ['ADNOC LNG']
# ['EmiratesLNG']
# ['ADNOC']
# ['ADNOC']
# ['DUSUP']
# ['ADNOC']
# ['Yemen LNG']
# ['Yemen LNG']
# ['Australian Industrial Energy']
# ['Venice Energy']
# ['PetroChina Co Ltd', 'Yantai Port Group']
# ['Yueyang LNG Co Ltd']
# ['First Gen', 'Tokyo Gas']
# ['Engro Corporation', 'Shell', 'Gunvor Group', 'Fatima Energy']
# ['KOGAS']
# ['Taiwan Electric Power Company']
# ['Rupantarita Prakritik Gas Company']
# ['LNG Gorskaya']
# ['LNG Gorskaya']
# ['LNG Gorskaya']
# ['BOTAŞ']
# ['Gazprom', 'Petrel Resources']
# ['BP', 'other']
# ['Excelerate Energy']
# ['Excelerate Energy']
# ['PDVSA', 'Shell', 'ExxonMobil', 'Mitsubishi']
# ['Rosneft', 'PDVSA']
# ['PDVSA']
# ['PDVSA']
# ['Tak-Iranian Gas Company']
# ['Tak-Iranian Gas Company']
# ['Tak-Iranian Gas Company']
# ['Steelhead LNG']
# ['GNL Quebec']
# ['GNL Quebec']
# ['Exelon Corporation']
# ['Excelerate Energy']
# ['Höegh Evi', 'Mitsui O.S.K. Lines']
# ['Northern Star Natural Gas']
# ['Freeport-McMoRan Inc', 'United LNG LP']
# ['Freeport-McMoRan Inc', 'United LNG LP']
# ['Freeport-McMoRan Inc', 'United LNG LP']
# ['Freeport-McMoRan Inc', 'United LNG LP']
# ['Freeport-McMoRan Inc', 'United LNG LP']
# ['Freeport-McMoRan Inc', 'United LNG LP']
# ['Gulf Coast LNG Partners LP', 'KOGAS', 'LG International (America) Inc', 'Port Lavaca LNG Services LLC']
# ['TORP Terminal LP']
# ['NextDecade']
# ['NextDecade']
# ['NextDecade']
# ['Pointe LNG, LLC', 'Pointe Pipeline Company, LLC']
# ['Pointe LNG, LLC', 'Pointe Pipeline Company, LLC']
# ['Pointe LNG, LLC', 'Pointe Pipeline Company, LLC']
# ['Excelerate Energy']
# ["Weaver's Cove Energy"]
# ['Crown Landing LLC']
# ['Cheniere Energy']
# ['Broadwater Energy LLC']
# ['Chevron']
# ['Mitsubishi', 'ConocoPhillips']
# ['Quoddy Bay LNG']
# ['Samson Oil & Gas Limited']
# ['Downeast LNG Inc']
# ['AES Corporation']
# ['Jefferies Financial Group']
# ['Jefferies Financial Group']
# ['Jefferies Financial Group']
# ['Atlantic Sea Island Group']
# ['Leif Höegh & Co']
# ['Woodside Energy']
# ['Engie']
# ['Canadian Superior Energy']
# ['Barca LNG LLC']
# ['Bradford County Real Estate Partners LLC']
# ['Bradford County Real Estate Partners LLC']
# ['BP', 'Kosmos Energy', 'Petrosen', 'SMH']
# ['BP', 'Kosmos Energy', 'Petrosen', 'SMH']
# ['BP', 'Kosmos Energy', 'Petrosen', 'SMH']
# ['BP', 'Kosmos Energy', 'Petrosen', 'SMH']
# ['BP', 'Kosmos Energy', 'Petrosen', 'SMH']
# ['Indian Oil Corporation Limited', 'Tamil Nadu Industrial Development Corporation']
# ['Vopak', 'Swedegas']
# ['CELSE (Centrais Elétricas de Sergipe S.A.)']
# ['Haytrac Power & Gaz SA']
# ['Excelerate Energy']
# ['GCL-Poly']
# ['GCL-Poly']
# ['GCL-Poly']
# ['TotalEnergies']
# ['New Fortress Energy']
# ['Kuwait National Petroleum Company']
# ['Kuwait National Petroleum Company']
# ['Northeast Midstream LP', 'North Shore LNG Project']
# ['Northeast Midstream LP', 'North Shore LNG Project']
# ['Northeast Midstream LP', 'North Shore LNG Project']
# ['Northeast Midstream LP', 'North Shore LNG Project']
# ['Northeast Midstream LP', 'North Shore LNG Project']
# ['PEMEX']
# ['Avocet LNG']
# ['General American LNG']
# ['Unidad de Planeación Minero Energética (UPME)']
# ['Energía del Pacífico']
# ['Gastrade']
# ['Shell', 'Government of Gibraltar']
# ['Depositi Italiani GNL']
# ['New Fortress Energy']
# ['EGAS']
# ['EGAS']
# ['Gasum']
# ['Prumo Logistica', 'Siemens', 'BP']
# ['Resources Energy Inc.']
# ['New Fortress Energy']
# ['Sunagas']
# ['New Fortress Energy']
# ['New Fortress Energy']
# ['New Fortress Energy']
# ['New Fortress Energy']
# ['PTT']
# ['ConocoPhillips']
# ['ExxonMobil']
# ['PT Perusahaan Gas Negara', 'PT Pelindo III']
# ['PT Sulawesi Satu']
# ['PT Perusahaan Gas Negara']
# ['Niihama LNG Co Ltd']
# ['Petronet LNG']
# ['Pandora LNG Joint Venture']
# ['Repsol', 'Horizon Oil']
# ['China National Offshore Oil Corp', 'Phoenix Petroleum']
# ['Gazprom LNG Portovaya LLC']
# ['Gazprom LNG Portovaya LLC']
# ['Gazprom']
# ['Novatek', 'Gazprombank']
# ['Novatek', 'Gazprombank']
# ['Cambodia Natural Gas Corporation']
# ['Cambodia Natural Gas Corporation']
# ['Zhejiang Hangjiaxin Clean Energy Co Ltd']
# ['National Pipe Network Group Nanshan (Shandong) Natural Gas Co Ltd']
# ['National Pipe Network Group Nanshan (Shandong) Natural Gas Co Ltd']
# ['KOGAS']
# ['Tobu Gas']
# ['SHEN ZHEN SINO-BENNY LPG CO LTD']
# ['SHEN ZHEN SINO-BENNY LPG CO LTD']
# ['Inversiones GNL Talcahuano SpA']
# ['CFEnergía']
# ['Linde']
# ['Hanseatic Energy Hub']
# ['BarMalGas']
# ['NextDecade']
# ['HIGAS']
# ['Skulte LNG Terminal', 'Virši-A']
# ['Petoro', 'Equinor', 'ConocoPhillips', 'Eni']
# ['Molgas', 'TotalEnergies', 'Equinor']
# ['Molgas', 'TotalEnergies', 'Equinor']
# ['Molgas', 'TotalEnergies', 'Equinor']
# ['Gasum']
# ['Gaz-System']
# ['Gaz-System']
# ['Gasum']
# ['Gasnor']
# ['SPOT Terminal Services LLC']
# ['Axis Midstream Holdings']
# ['Lone Star Ports LLC']
# ['Enbridge', 'Oiltanking GmbH']
# ['Trafigura']
# ['Bluewater Texas Terminal LLC']
# ['Bluewater Texas Terminal LLC']
# ['Tallgrass Energy']
# ['Blue Marlin Offshore Port LLC']
# ['JupiterMLP LLC']
# ['LOOP LLC']
# ['Hainan Shennan Energy Co.,ltd CNPC']
# ['New Fortress Energy']
# ['Corban Energy Group']
# ['KARMOL']
# ['Mozambique Rovuma Venture', 'ADNOC', 'KOGAS', 'ENH']
# ['Hebei Jinjianjia Natural Gas Co Ltd']
# ['Yuhuan Damaiyu Junan LNG Co Ltd']
# ['Zhongtie Gallon (Shandong) Liquefied Natural Gas Co Ltd']
# ['Guangdong (Panyu) Petrochemical Storage & Transportation Ltd']
# ['Guangdong (Panyu) Petrochemical Storage & Transportation Ltd']
# ['Guangdong Huizhou LNG Co Ltd']
# ['Guangdong Huizhou LNG Co Ltd']
# ['Sinopec Zhoushan LNG Co Ltd']
# ['Sinopec Zhoushan LNG Co Ltd']
# ['Sinopec Yantai Longkou LNG Co Ltd']
# ['Sinopec Yantai Longkou LNG Co Ltd']
# ['Baichuan Energy (Suizhong) LNG Co Ltd']
# ['Baichuan Energy (Suizhong) LNG Co Ltd']
# ['Baichuan Energy (Suizhong) LNG Co Ltd']
# ['China National Petroleum Corporation', 'SK Group', 'Weihai Nanhai New District Administration']
# ['Hubei Minsheng Liquefied Petroleum Gas Ltd']
# ['HPCL Shapoorji Energy Private Limited']
# ['East Coast Concessions Private Limited']
# ['Bengal Concessions Private Limited']
# ['Atlantic Gulf and Pacific Company']
# ['Atlantic Gulf and Pacific Company']
# ['Tokyo Electric Power Company', 'Chubu Electric Power']
# ['BOTAŞ']
# ['AECOM Capital', 'DKRW Energy']
# ['AECOM Capital', 'DKRW Energy']
# ['Sempra Energy']
# ['Sempra Energy', 'TotalEnergies']
# ['Sempra Energy', 'TotalEnergies']
# ['Caofeidian Xintian LNG Co Ltd']
# ['Caofeidian Xintian LNG Co Ltd']
# ['Caofeidian Xintian LNG Co Ltd']
# ['Guangdong Yangjiang Hailingwan LNG Co Ltd']
# ['Zhejiang Zheneng Liuheng LNG Co Ltd']
# ['Zhejiang Zheneng Liuheng LNG Co Ltd']
# ['Macau Natural Gas Co Ltd']
# ['QatarEnergy', 'TotalEnergies', 'Shell', 'ExxonMobil', 'ConocoPhillips', 'Eni', 'Sinopec', 'China National Petroleum Corporation']
# ['QatarEnergy', 'TotalEnergies', 'Shell', 'ExxonMobil', 'ConocoPhillips', 'Eni', 'Sinopec', 'China National Petroleum Corporation']
# ['QatarEnergy', 'TotalEnergies', 'Shell', 'ExxonMobil', 'ConocoPhillips', 'Eni', 'Sinopec', 'China National Petroleum Corporation']
# ['QatarEnergy', 'TotalEnergies', 'Shell', 'ExxonMobil', 'ConocoPhillips', 'Eni', 'Sinopec', 'China National Petroleum Corporation']
# ['QatarEnergy', 'TotalEnergies', 'Shell', 'ConocoPhillips']
# ['QatarEnergy', 'TotalEnergies', 'Shell', 'ConocoPhillips']
# ['New Fortress Energy']
# ['Morocco Ministry of Energy, Mining and Sustainable Development']
# ['TotalEnergies', 'Matola Gas Company']
# ['Delta Offshore Energy']
# ['Pars Energy']
# ['Höegh Evi']
# ['NewMed Energy', 'Chevron', 'Ratio Energies']
# ['Gazprom Flot']
# ['YPF', 'Petronas']
# ['YPF', 'Petronas']
# ['YPF', 'Petronas']
# ['Sycar LLC']
# ['Cyropeak LNG Solutions']
# ['TotalEnergies', 'SOCAR', 'Shell', 'PetroCI', 'Golar LNG', 'CI-Energies', 'Endeavor Energy']
# ['Calais LNG']
# ['Okinawa Electric Power']
# ['National Grid']
# ['ConocoPhillips']
# ['AES Corporation']
# ['4Gas']
# ['ConocoPhillips']
# ['Chevron']
# ['BP']
# ['Clearwater Port LNG']
# ['Esperanza Energy LLC']
# ['Pangea LNG']
# ['Pangea LNG']
# ['Kansai Electric Power']
# ['Excelerate Energy']
# ['Bharat Gas Resources Ltd ', 'Petronet LNG']
# ['Delaware River Partners LLC']
# ['LNG Group Panama']
# ['Predator Oil & Gas']
# ['Totisa Holdings']
# ['Dongfang Group', 'Jinzhou Port Co., Ltd', 'United Energy Group', 'Trafigura']
# ['Beijing Gas Group (Tianjin) LNG Co Ltd']
# ['Beijing Gas Group (Tianjin) LNG Co Ltd']
# ['Beijing Gas Group (Tianjin) LNG Co Ltd']
# ['Western Gas']
# ['Excelerate Energy']
# ['PT Perusahaan Gas Negara']
# ['JFE Engineering', 'MedcoEnergi']
# ['Karpowership']
# ['PT Australasia LNG Indonesia']
# ['Pertamina']
# ['Chugoku Electric Power']
# ['City of Sendai Gas Bureau']
# ['Hokuriku Electric']
# ['TTCL']
# ['Zhefu Holding Group Co Ltd', 'Supreme Trading Co Ltd']
# ['CNTIC VPower', 'Myanmar Business Consultant Group Limited']
# ['Energas Terminal Pvt Ltd']
# ['Pakistan GasPort Consortium Limited']
# ['Tabeer Energy (Pvt) Ltd', 'Tabeer Energy Marketing (Pvt) Ltd']
# ['Tabeer Energy (Pvt) Ltd', 'Tabeer Energy Marketing (Pvt) Ltd']
# ['Batangas Clean Energy Inc']
# ['Singapore Energy Market Authority']
# ['Singapore LNG Corporation']
# ['Northeast Asia LNG Hub Terminal Co Ltd']
# ['Taiwan Electric Power Company']
# ['Korea Western Power', 'Thai Petrochemical Industry Polene Power', 'KOGAS']
# ['Gulf MPT LNG Terminal Co Ltd']
# ['Gulf MPT LNG Terminal Co Ltd']
# ['EGAT']
# ['PTT']
# ['Novatek']
# ['Chan May LNG']
# ['Energy Capital Vietnam']
# ['Panbil Group']
# ['CNTIC VPower']
# ['Luzon LNG Terminal Inc']
# ['TotalEnergies Gas & Power', 'Siemens Myanmar']
# ['Petronas']
# ['SOCAR']
# ['New Age (African Global Energy) Ltd', 'Lukoil', 'Bowleven']
# ['Ksi Lisims LNG GP Ltd.']
# ['National Iranian Oil Company']
# ['National Iranian Oil Company']
# ['LNG Alliance', 'Epcilon LNG LLC']
# ['LNG Alliance', 'Epcilon LNG LLC']
# ['Arctic LNG-1 LLC']
# ['Novatek']
# ['Novatek']
# ['Qilak Energy']
# ['Excelerate Energy', 'ExxonMobil', 'Ministry of Infrastructure and Energy of Albania']
# ['Petrobras']
# ['New Fortress Energy']
# ['Cosan']
# ['Hidrovias do Brasil Vila do Conde SA']
# ['Imetame Energia SA']
# ['TISA (Termelétrica Itacoatiara SA)']
# ['Copel', 'Shell']
# ['Porto Norte Fluminense SA']
# ['Porto Central Complexo Industrial Portuário SA']
# ['New Fortress Energy']
# ['Aruanã Energia']
# ['Eneva', 'Grupo Vale Azul Participações']
# ['New Fortress Energy']
# ['Top Speed Energy']
# ['PetroChina Co Ltd']
# ['Tangshan Jingcao Natural Gas Co Ltd']
# ['China Overseas Smart City Technology Group Co., Ltd.', 'Caofeidian Financial Holding Group Co., Ltd.']
# ['Huaying Natural Gas Co Ltd']
# ['Huaying Natural Gas Co Ltd']
# ['China Energy Reserve and Chemicals Group Company Limited']
# ['China Huadian Group Corp']
# ['Shandong Hainuo Port Co., Ltd']
# ['Shanghai Hong Hua Oil and Gas Equipment Co Ltd']
# ['Jiangsu Jiasheng Investment Co Ltd']
# ['Jiangxi Investment Gas Co Ltd']
# ['Liaoning Energy Investment Group', 'Panjin State Owned Asset Investment Management Group Co Ltd', 'Liaoning Baoheng Oil & Natural Gas Co Ltd']
# ['Quanzhou Honghai Petrochemical Storage Co Ltd']
# ['Quanzhou Honghai Petrochemical Storage Co Ltd']
# ['Beijing Energy International Holding Co', 'Xinfa Holding Co., Ltd.']
# ['Jiangsu Guoxin LNG Co Ltd']
# ['Jiangsu Guoxin LNG Co Ltd']
# ['Zhongtie Gallon (Linhai) Liquefied Natural Gas Co Ltd']
# ['Wenzhou Huagang Petrochemical Port Company']
# ['China National Offshore Oil Corp']
# ['Aguadulce LNG']
# ['SP Armada Clean Energy Ventures']
# ['Lebanese Ministry of Energy and Water']
# ['Lebanese Ministry of Energy and Water']
# ['Lebanese Ministry of Energy and Water']
# ['New Fortress Energy']
# ['Golar LNG']
# ['Atlantic Gulf and Pacific Company']
# ['Pearl Energy Pvt Ltd', 'SOCAR Trading']
# ['SK Group']
# ['Sharjah National Oil Corporation']
# ['Venture Global CP2 LNG, LLC']
# ['Venture Global CP2 LNG, LLC']
# ['EVN']
# ['Energy Capital Vietnam', 'Gunvor International', 'B.Grimm Power']
# ['Shell Energy']
# ['Vires Energy']
# ['Millennium Energy']
# ['ExxonMobil', 'JERA', "Hai Phong People's Committee"]
# ['Vopak']
# ['Viva Energy']
# ['Gazprom']
# ['Sempra Energy', 'CFEnergía', 'TotalEnergies']
# ['Venture Global Delta LNG, LLC']
# ['Venture Global Delta LNG, LLC']
# ['West Delta LNG, LLC']
# ['Grupo Cobra']
# ['YPFB']
# ['Dioriga Gas']
# ['Blue Marlin Offshore Port LLC']
# ['Texas Gulflink LLC']
# ['A-Property', 'Globaltek', 'Zhejiang Energy']
# ['A-Property', 'Globaltek', 'Zhejiang Energy']
# ['EemsEnergyTerminal BV']
# ['Nord West Ölleitung']
# ['Tree Energy Solutions']
# ['New Fortress Energy Louisiana LLC']
# ['Eni Congo']
# ['Estonian Stockpiling Agency']
# ['Gastrade']
# ['Mediterranean Gas']
# ['TotalEnergies']
# ['Elpedison']
# ['FGEN LNG']
# ['JupiterMLP LLC']
# ['NuStar Energy']
# ['CPC Corporation']
# ['LNG Newfoundland and Labrador Ltd', 'Horizon Maritime Services']
# ['FortisBC']
# ['FortisBC']
# ['FortisBC']
# ['FortisBC']
# ['New Fortress Energy']
# ['KARMOL']
# ['West Africa LNG Group']
# ['West Africa LNG Group']
# ['Summit Oil and Shipping Co Ltd']
# ['UTM Offshore', 'Nigerian National Petroleum Corporation', 'Delta State Government']
# ['Crown LNG India AS']
# ['New Mangalore Port Trust', 'LNG Alliance']
# ['China Firm for the Investment of Technology Co Ltd']
# ['New Fortress Energy']
# ['Kunlun Energy Co Ltd']
# ['Snam']
# ['T&T Group', 'Hanwa', 'KOSPO', 'KOGAS']
# ['Snam']
# ['Petronas']
# ['Gasum Oy']
# ['Marubeni Corporation', 'Sumitomo Corporation', 'Mitsui & Co', 'Eden Group']
# ['OOO Arctic LNG 3']
# ['Rosneft']
# ['New Fortress Energy']
# ['New Fortress Energy']
# ['New Fortress Energy']
# ['New Fortress Energy']
# ['New Fortress Energy']
# ['New Fortress Energy']
# ['Aslan Energy Capital', 'PT Agri Maritim Sulteng']
# ['EGAT', 'PTT']
# ['Government of Papua New Guinea', 'Dirio Gas & Power', 'Twenty20 Energy']
# ['Government of Papua New Guinea', 'Dirio Gas & Power', 'Twenty20 Energy']
# ['Government of Papua New Guinea', 'Dirio Gas & Power', 'Twenty20 Energy']
# ['Government of Papua New Guinea', 'Dirio Gas & Power', 'Twenty20 Energy']
# ['Government of Papua New Guinea', 'Dirio Gas & Power', 'Twenty20 Energy']
# ['Government of Papua New Guinea', 'Dirio Gas & Power', 'Twenty20 Energy']
# ['Government of Papua New Guinea', 'Dirio Gas & Power', 'Twenty20 Energy']
# ['Government of Papua New Guinea', 'Dirio Gas & Power', 'Twenty20 Energy']
# ['Government of Papua New Guinea', 'Dirio Gas & Power', 'Twenty20 Energy']
# ['Government of Papua New Guinea', 'Dirio Gas & Power', 'Twenty20 Energy']
# ['Government of Papua New Guinea', 'Dirio Gas & Power', 'Twenty20 Energy']
# ['Government of Papua New Guinea', 'Dirio Gas & Power', 'Twenty20 Energy']
# ['Thai Binh LNG Power Joint Stock Company']
# ['ExxonMobil', 'Tokyo Electric Power Company', 'Chubu Electric Power']
# ['Deutsche ReGas']
# ['GEIL']
# ['Penn America Energy']
# ['Eneva', 'Servtec Energia']
# ['Sinolam Smarter Energy']
# ['Caribbean LNG']
# ['Gasunie', 'Oiltanking', 'Vopak LNG']
# ['PT Petrogas Jatim Utama', 'Woodside Energy']
# ['Hanseatic Energy Hub']
# ['Government of Bangladesh']
# ['Mozambique Rovuma Venture', 'Galp', 'KOGAS', 'ENH']
# ['BP', 'Kosmos Energy']
# ['Kosmos Energy', 'Petrosen']
# ['Manzanillo Gas & Power']
# ['Snam']
# ['FSRU Italia']
# ['Tree Energy Solutions', 'E.ON', 'Engie']
# ['RWE', 'Stena Power & LNG Solutions']
# ['VTTI']
# ['Gasunie']
# ['RomGaz', 'SOCAR']
# ['RomGaz', 'SOCAR']
# ['LNG Alliance', 'EPCG']
# ['Pakistan State Oil']
# ['LNG Easy', 'Punjab Group']
# ['ADNOC']
# ['ADNOC']
# ['Liaoning Energy Investment (Group) Co Ltd']
# ['Perenco']
# ['Mai-Liao Power Corporation']
# ['Rudong Yangkou Port Liquefied Products Terminal Co Ltd']
# ['CPC Corporation']
# ['Murmansk LNG LLC']
# ['Murmansk LNG LLC']
# ['Murmansk LNG LLC']
# ['Gazprom Helium Service']
# ['CFEnergía']
# ['Sycar LLC', 'PDVSA']
# ['WEB Aruba NV', 'Eagle LNG Partners Jacksonville LLC']
# ['Shell', 'BPL (Bahamas Power & Light)']
# ['Tamboran']
# ['KARMOL']
# ['Buru Energy']
# ['Nimofast', 'other']
# ['GDE Energia']
# ['Eni Congo']
# ['Eni', 'ExxonMobil', 'China National Petroleum Corporation', 'ENH', 'KOGAS', 'ADNOC']
# ['Golar LNG']
# ['Vopak Terminal Durban']
# ['Vopak Terminal Durban']
# ['Port Edward LNG Ltd']
# ['Gulfstream LNG Development LLC']
# ['Grand Isle LNG Operating Co LLC']
# ['Grand Isle LNG Operating Co LLC']
# ['Nopetro Energy']
# ['Korea National Oil Corp', 'SK Gas', 'MOL Chemical Tankers']
# ['Korea National Oil Corp', 'SK Gas', 'MOL Chemical Tankers']
# ['POSCO International', 'LX International']
# ['Mowi']
# ['Crown LNG Holdings Ltd']
# ['Pilot LNG']
# ['Firebird LNG']
# ['Petronas']
# ['Deutsche ReGas']
# ['Deutsche ReGas']
# ['ACWA Power']
# ['Pertamina']
# ['PBDB', 'GE']
# ['Petronet LNG']
# ['Petronet LNG']
# ['Bumi Armada', 'Pertamina Internaional Shipping']
# ['PT Layar Nusantara Gas']
# ['Atimonan One Energy']
# ['Jiangsu Huaxin Yongnan Energy Technology Co., Ltd.']
# ['LNG Yakutia LLC']
# ['LNG Yakutia LLC']
# ['Arkhangelsk LNG LLC']
# ['Arkhangelsk LNG LLC']
# ['Rosneft']
# ['Argent LNG LLC']
# ['Argent LNG LLC']
# ['PT AKR Corporindo', 'BP Gas & Power Investments']
# ['PLN Energi Primer Indonesia', 'AG&P Indonesia', 'Suasa Benua Sukses', 'KPMOG']
# ['Government of Cambodia']
# ['Quezon Power Philippines Ltd Co']
# ['Ace Gas & FLNG Co Ltd']
# ['Transoceanic Gas & Power']
# ['Riverside LNG']
# ['WaveCrest Energy LLC']
# ['Zhongjiao Yingkou liquefied Natural Gas Co Ltd']
# ['Pilot LNG', 'GFI (Gomez Family International)']
# ['Golar LNG', 'Pan American Energy']
# ['Excelerate Energy', 'ITECO JSC']
# ['Excelerate Energy', 'ITECO JSC']
# ['TGS - Transportadora de Gas del Sur SA']
# ['Deutsche Regas']
# ['Venture Global Plaquemines LNG, LLC']
# ['Twinza Oil Ltd']
# ['Gazprom']
# ['Gato Negro Permitium Uno, S.A.P. I. de C.V.']

# %%
pid_list = list(po_dict.keys())

owner_parent_strings_df = pandas.DataFrame(index=pid_list, columns=[#'OwnerList','ParentList',
                                                                    'OwnerString','ParentString','ParentHQCountry'])
#                                                                    'OwnerPercentsArrayWithNans','ParentPercentsArrayWithNans',
#                                                                    'OwnerPercentsArray','ParentPercentsArray',
#                                                                    'ParentOwnrshpArray'])

# %%
po_dict['T039800']
# Out:
# {'owner_parent_links': {'Shandong Penglai Baota Yina Natural Gas Co Ltd': {'owner_pct_val': np.float64(1.0),
#    'parent_list': ['Pagoda Investment Holding Co Ltd'],
#    'parent_pct_vals': [np.float64(1.0)],
#    'parent_hq_country_list': ['China']}},
#  'owner_list': ['Shandong Penglai Baota Yina Natural Gas Co Ltd'],
#  'owner_pct_vals': [np.float64(1.0)]}

# %%
for combo_id in comboid_list:
    
    # get list of owners
    owner_list = po_dict[combo_id]['owner_list']#.keys()
    owner_pct_vals = po_dict[combo_id]['owner_pct_vals']
    all_parents_list = []
    all_parents_normalized_pct_vals = []
    all_parents_hq_country_list = []
    
    for owner in owner_list:
        owner_pct_val = [ po_dict[combo_id]['owner_parent_links'][owner]['owner_pct_val'] ]
        parent_list = po_dict[combo_id]['owner_parent_links'][owner]['parent_list']
        parent_hq_country_list = po_dict[combo_id]['owner_parent_links'][owner]['parent_hq_country_list']
        
        parent_pct_vals = numpy.array(po_dict[combo_id]['owner_parent_links'][owner]['parent_pct_vals'])
        
        parent_normalized_pct_vals = list(parent_pct_vals * owner_pct_val)
        
        all_parents_list += parent_list
        all_parents_normalized_pct_vals += parent_normalized_pct_vals
        all_parents_hq_country_list += parent_hq_country_list
    
    owner_frac_df = pandas.DataFrame({'Owners':owner_list,'OwnerFractions':owner_pct_vals})#.dropna(how='all') # drop nan rows   
    parent_frac_df = pandas.DataFrame({'Parents':all_parents_list,
                                       'ParentFractions':all_parents_normalized_pct_vals,
                                       'ParentHQCountries':all_parents_hq_country_list})
    
    # sum any of the same owners/parents
    owner_frac_df = pandas.DataFrame(owner_frac_df.groupby(by=['Owners'], dropna=False)['OwnerFractions'].sum(min_count=1))
    parent_frac_df = pandas.DataFrame(parent_frac_df.groupby(by=['Parents'], dropna=False)['ParentFractions'].sum(min_count=1))
    
    owner_frac_df.sort_values('OwnerFractions', ascending=False, inplace=True)
    parent_frac_df.sort_values('ParentFractions', ascending=False, inplace=True)
    
    try:
        parent_hq_country_list = [parents_df.loc[p].ParentHQCountry for p in parent_frac_df.index.tolist()]
    except KeyError:
        parent_hq_country_list = []
        for p in parent_frac_df.index.tolist():
            try:
                parent_hq_country_list += [parents_df.loc[p].ParentHQCountry]
            except KeyError:
                parent_hq_country_list += ['unknown']

    parent_formatted_string = ('; ').join(list(parent_frac_df.index + (parent_frac_df['ParentFractions']*100).map(' [{:,.2f}%]'.format)))
    owner_formatted_string = ('; ').join(list(owner_frac_df.index + (owner_frac_df['OwnerFractions']*100).map(' [{:,.2f}%]'.format)))
    parent_hq_country_formatted_string = ('; ').join(parent_hq_country_list)

    parent_formatted_string = parent_formatted_string.replace('nan%', 'unknown %')
    owner_formatted_string = owner_formatted_string.replace('nan%', 'unknown %')
    
    owner_parent_strings_df.loc[combo_id,'OwnerString'] = owner_formatted_string
    owner_parent_strings_df.loc[combo_id,'ParentString'] = parent_formatted_string
    owner_parent_strings_df.loc[combo_id,'ParentHQCountry'] = parent_hq_country_formatted_string
    
    owner_parent_strings_df.replace('','--',inplace=True)

# %%
owner_parent_strings_df.loc['T039800']
# Out:
# OwnerString        Shandong Penglai Baota Yina Natural Gas Co Ltd...
# ParentString              Pagoda Investment Holding Co Ltd [100.00%]
# ParentHQCountry                                                China
# Name: T039800, dtype: object

# %%
now_string = datetime.datetime.now().strftime('%Y-%m-%d')
owner_parent_strings_df[['OwnerString','ParentString','ParentHQCountry']].to_excel('GEM-terminals-owner-parent-strings-'+now_string+'.xlsx')
#owner_parent_strings_df.to_excel('GEM-terminals-owner-parent-strings-'+now_string+'.xlsx')
